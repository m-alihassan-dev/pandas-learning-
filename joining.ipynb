# %%
import numpy as np
import pandas as pd

# %%
df_students = pd.DataFrame({
    'Name': ['Ali', 'Sara', 'Ahmed'],
    'Age': [21, 22, 20]
}, index=[1, 2, 3])

df_marks = pd.DataFrame({
    'CGPA': [3.5, 3.8, 3.2]
}, index=[1, 2, 4])

# %%
df_students

# %%
df_marks

# %%
df_students.join(df_marks)

# %%
df_students.join(df_marks, how='inner')

# %%
df_students.join(df_marks, how='outer')

# %%
df_students.join(df_marks, how='right')
