# %%
import pandas as pd

# %% [markdown]
# Creating DataFrames

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df = pd.DataFrame(data)

# %%
df

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

df2 = pd.DataFrame(data_list)

# %%
df2

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

df2 = pd.DataFrame(data_list, columns=['Name', 'Age', 'City', 'Salary'])

# %%
df2

# %% [markdown]
# Selecting a Single Column

# %%
df

# %%
df['Name']

# %% [markdown]
# Selecting Multiple Columns

# %%
df[['Name', 'Age']]

# %% [markdown]
# Creating a New Column using Values

# %%
df['Role'] = ['Manager', 'Developer', 'Designer', 'Analyst']

# %%
df

# %% [markdown]
# Removing Columns

# %%
df.drop('Role', axis=1)

# %%
df

# %%
df.drop('Role', axis=1, inplace=True)

# %%
df

# %%
df.drop(['Age', 'Salary'], axis=1)

# %%
df.drop(columns=['Age', 'Salary'], axis = 1)

# %% [markdown]
# Indexing Columns by Position

# %%
df.iloc[:, 0]

# %%
df.iloc[:, [0, 2]]

# %%
df.iloc[:, 0:2]

# %% [markdown]
# Indexing Columns by Labels

# %%
df.loc[:, 'Age']

# %%
df.loc[:, ['Name', 'Age']]

# %% [markdown]
# Get Column Index Number

# %%
df.columns.get_loc('Name')

# %% [markdown]
# Change Column Order using Indexing

# %%
df = df[['Name', 'City', 'Salary', 'Age']]
df

# %% [markdown]
# Selecting Rows by Index Label

# %%
df.loc[0]

# %%
df.loc[[0, 2]]

# %%
df.loc[0:1]

# %% [markdown]
# Selecing Rows by Position

# %%
df.iloc[0]

# %%
df.iloc[[0, 2]]

# %%
df.iloc[0:2]

# %% [markdown]
# Selecing Subsets of Rows and Columns using Label/Index (Recommended)

# %%
df.loc[0:1, ['Name', "Age"]]

# %% [markdown]
# Selecting Substs of Rows and Columns using Position

# %%
df.iloc[0:2, 1:3]
